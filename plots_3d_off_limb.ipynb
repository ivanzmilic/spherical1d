# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
spectrum = fits.open("test_off_limb.fits")[0].data

# %%
spectrum.shape
# Out:
# (1912,)

# %%
plt.plot(spectrum)

# %%
pop = fits.open('/dat/milic/0_lwsynth_393.1.fits')[2].data

# %%
pop.shape
# Out:
# (768, 768, 6, 256)

# %%
plt.semilogy(pop[0,0,0,:])

# %%
# Gotta figure out where the actual limb is:
